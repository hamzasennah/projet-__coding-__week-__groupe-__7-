# %% [markdown]
# ## 🧪 Automated Testing Results
#
# Afin de garantir la fiabilité du pipeline de traitement des données ainsi que l’intégration du modèle de machine learning, des **tests automatisés** ont été implémentés en utilisant le framework **pytest**. Ces tests permettent de vérifier automatiquement le bon fonctionnement des principales composantes du projet et de s’assurer que certaines étapes critiques du pipeline fonctionnent correctement.
#
# Dans ce projet, trois tests principaux ont été réalisés :
#
# * **Vérification de la gestion des valeurs manquantes** afin de confirmer que le dataset nettoyé ne contient aucune donnée manquante.
# * **Validation de la fonction `optimize_memory(df)`**, qui permet de réduire l’utilisation de la mémoire en optimisant les types de données du dataset.
# * **Vérification du chargement du modèle de machine learning**, afin de s’assurer que le modèle sauvegardé (`.pkl`) peut être chargé correctement pour être utilisé dans les étapes de prédiction.
#
# Les tests ont été exécutés à l’aide de la commande suivante :
#
# ```bash
# python -m pytest -v -s
# ```
#
# Résultat obtenu :
#
# ```text
# ============================= test session starts =============================
# platform win32 -- Python 3.11.5, pytest-7.4.0
# collected 3 items
#
# tests/test_data_processing.py::test_missing_values PASSED
# tests/test_data_processing.py::test_optimize_memory PASSED
# tests/test_data_processing.py::test_model_loading PASSED
#
# ============================== 3 passed in 15.41s ==============================
# ```
#
# Ces résultats indiquent que **les trois tests automatisés ont été exécutés avec succès**, ce qui confirme que les étapes principales du pipeline — notamment le prétraitement des données, l’optimisation de la mémoire et le chargement du modèle — fonctionnent correctement. L’implémentation de ces tests automatisés permet ainsi d’assurer la **robustesse, la fiabilité et la reproductibilité** du projet de machine learning.
